# %%
import  pandas as pd
import matplotlib as mat
import seaborn as sns

# %%
import pandas as pd
iris = pd.read_excel('dropoutlist.xlsx','Dropout of gujarat')

# %%
import pandas as pd
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','Boys','B.drop no','Girls','Gdno','Total','dno','Reason1','Reason2','Reason3'])
df = df.dropna(how='all')

# %%
obj = df.head(25)
obj
# Out:
#     District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 0       Ahmedabad  470423.0  17170.4395  380844.0  11958.5  851267.0
# 1          Amreli  144187.0   6791.2077  104832.0  5346.43  249019.0
# 2           Anand  179808.0   6275.2992  142036.0  5894.49  321844.0
# 3     Banaskantha  277490.0  17426.3720  177149.0  10912.4  454640.0
# 4         Bharuch  147484.0   7241.4644   68824.0  3702.73  216309.0
# 5       Bhavnagar  268108.0  12895.9948  220706.0  11278.1  488814.0
# 6           Botad  187988.0  14794.6556  123117.0   9997.1  311105.0
# 7           Dangs   25055.0   2287.5215   23918.0  2784.06   48973.0
# 8     Gandhinagar  125443.0   4904.8213   97864.0  3444.81  223307.0
# 9        Jamnagar  169875.0   6964.8750  120644.0     7118  290519.0
# 10   ChotaUdaipur   22130.0   1949.6530   15262.0  1691.03   37392.0
# 11          Kheda  211139.0  13787.3767  139500.0  10155.6  350638.0
# 12          Kutch  139500.0   7281.9000  109673.0  7655.18  249172.0
# ...

# %%
import matplotlib.pyplot as mat 
mat.show()

# %%
obj.plot.bar(figsize=(20,10),width=2.5,fontsize=15)

# %%
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','BDP','GDP','T%'])
df = df.dropna(how='all')

# %%
df
# Out:
#     District Name   BDP    GDP     T%
# 0       Ahmedabad  3.65   3.14   3.37
# 1          Amreli  4.71   5.10   4.84
# 2           Anand  3.49   4.15   3.82
# 3     Banaskantha  6.28   6.16   6.44
# 4         Bharuch  4.91   5.38   5.12
# 5       Bhavnagar  4.81   5.11   4.94
# 6           Botad  7.87   8.12   7.95
# 7           Dangs  9.13  11.64  10.29
# 8     Gandhinagar  3.91   3.52   3.72
# 9        Jamnagar  4.10   5.90   5.00
# 10   ChotaUdaipur  8.81  11.08   9.60
# 11          Kheda  6.53   7.28   6.91
# 12          Kutch  5.22   6.98   6.10
# 13        Mehsana  4.69   4.97   4.81
# 14      Mahisagar  4.97   5.02   4.99
# 15        Navsari  5.49   6.75   6.12
# 16    Panchmahals  5.12   6.28   5.70
# 17          Patan  5.33   5.80   5.55
# 18      Porbandar  8.33   8.97   8.65
# 19         Rajkot  4.05   3.60   3.89
# 20    Sabarkantha  6.87   7.37   7.08
# 21          Surat  3.78   3.31   3.54
# 22  Surendranagar  3.82   4.96   4.39
# 23       Vadodara  4.27   3.90   4.14
# ...

# %%
df.plot.bar(figsize=(17,10),width=.8,fontsize=15)

# %%
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','Boys','B.drop no','Girls','Gdno','Total','dno'])
cd = df.iloc[[8,3,20,13,17]]
print(df.iloc[[8,3,20,13,17]])
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(15,5),width=.8,fontsize=15)
plt.title('North Gujrat')
plt.show()
df = pd.read_excel('dropoutlist.xlsx',usecols=['BDP','GDP','T%'])
cd = df.iloc[[8,3,20,13,17]]
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(10,5),width=.8,fontsize=15)
plt.show()
# Out:
#    District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 8    Gandhinagar  125443.0   4904.8213   97864.0  3444.81  223307.0
# 3    Banaskantha  277490.0  17426.3720  177149.0  10912.4  454640.0
# 20   Sabarkantha  203737.0  13996.7319  169330.0  12479.6  373067.0
# 13       Mehsana  153916.0   7218.6604  117898.0  5859.53  271814.0
# 17         Patan  142043.0   7570.8919  104288.0   6048.7  246331.0
#
#            dno
# 8    8307.0204
# 3   29278.8160
# 20  26413.1436
# 13  13074.2534
# 17  13671.3705

# %%
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','Boys','B.drop no','Girls','Gdno','Total','dno'])
cd = df.iloc[[4,7,15,21,24]]
print(df.iloc[[4,7,15,21,24]])
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(15,5),width=.8,fontsize=15)
plt.title('South Gujrat')
plt.show()
df = pd.read_excel('dropoutlist.xlsx',usecols=['BDP','GDP','T%'])
cd = df.iloc[[4,7,15,21,24]]
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(10,5),width=.8,fontsize=15)
plt.show()
# Out:
#    District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 4        Bharuch  147484.0   7241.4644   68824.0  3702.73  216309.0
# 7          Dangs   25055.0   2287.5215   23918.0  2784.06   48973.0
# 15       Navsari   93651.0   5141.4399   87626.0  5914.76  181277.0
# 21         Surat  390824.0  14773.1472  299094.0  9900.01  689919.0
# 24        Valsad  106980.0   5466.6780   96316.0  5345.54  203296.0
#
#            dno
# 4   11075.0208
# 7    5039.3217
# 15  11094.1524
# 21  24423.1326
# 24  10795.0176

# %%
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','Boys','B.drop no','Girls','Gdno','Total','dno'])
cd = df.iloc[[1,5,6,9,19,22]]
print(df.iloc[[1,5,6,9,19,22]])
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(15,5),width=.8,fontsize=15)
plt.title('Saurashtra')
plt.show()
df = pd.read_excel('dropoutlist.xlsx',usecols=['BDP','GDP','T%'])
cd = df.iloc[[1,5,6,9,19,22]]
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(10,5),width=.8,fontsize=15)
plt.show()
# Out:
#     District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 1          Amreli  144187.0   6791.2077  104832.0  5346.43  249019.0
# 5       Bhavnagar  268108.0  12895.9948  220706.0  11278.1  488814.0
# 6           Botad  187988.0  14794.6556  123117.0   9997.1  311105.0
# 9        Jamnagar  169875.0   6964.8750  120644.0     7118  290519.0
# 19         Rajkot  264668.0  10719.0540  229445.0  8260.02  494112.0
# 22  Surendranagar  150385.0   5744.7070  117193.0  5812.77  267578.0
#
#            dno
# 1   12052.5196
# 5   24147.4116
# 6   24732.8475
# 9   14525.9500
# 19  19220.9568
# 22  11746.6742

# %%
df = pd.read_excel('dropoutlist.xlsx',usecols=['District Name','Boys','B.drop no','Girls','Gdno','Total','dno'])
cd = df.iloc[[0,2,10,11,16,23]]
print(df.iloc[[0,2,10,11,16,23]])
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(15,8),width=.8,fontsize=15)
plt.title('Central Gujrat')
plt.show()
df = pd.read_excel('dropoutlist.xlsx',usecols=['BDP','GDP','T%'])
cd = df.iloc[[0,2,10,11,16,23]]
import matplotlib.pyplot as plt
cd.plot.bar(figsize=(10,5),width=.8,fontsize=15)
plt.show()
# Out:
#    District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 0      Ahmedabad  470423.0  17170.4395  380844.0  11958.5  851267.0
# 2          Anand  179808.0   6275.2992  142036.0  5894.49  321844.0
# 10  ChotaUdaipur   22130.0   1949.6530   15262.0  1691.03   37392.0
# 11         Kheda  211139.0  13787.3767  139500.0  10155.6  350638.0
# 16   Panchmahals  113032.0   5787.2384   85260.0  5354.33  198292.0
# 23      Vadodara  299337.0  12781.6899  246939.0  9630.62  546277.0
#
#            dno
# 0   28687.6979
# 2   12294.4408
# 10   3589.6320
# 11  24229.0858
# 16  11302.6440
# 23  22615.8678

# %%
labels = 'North Gujrat', 'South Gujrat', 'Central Gujrat', 'Saurashtra'
sizes = [5.52,6.07,6.79,5.74]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0, 0, 0.1, 0)

plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140,radius=2,textprops={'fontsize': 18})

plt.axis('on')
plt.show()

# %%
import pandas as pd 
  
# initialize list of lists 
data = [['Excessive academic pressure from school and parents', 1000], ['lack of interest', 15000], ['Child labour', 5000], ['Education Not Considered necesaary', 1400], ['Bullying', 100], ['Diseases', 2000], ['Constant failurer', 600], ['financial backward', 2500], ['Language barrier', 7000], ['Distance between school and home', 1000]] 
  
# Create the pandas DataFrame 
frame = pd.DataFrame(data, columns = ['Reason', 'Dropout student']) 
  
# print dataframe. 
frame
# Out:
#                                               Reason  Dropout student
# 0  Excessive academic pressure from school and pa...             1000
# 1                                   lack of interest            15000
# 2                                       Child labour             5000
# 3                 Education Not Considered necesaary             1400
# 4                                           Bullying              100
# 5                                           Diseases             2000
# 6                                  Constant failurer              600
# 7                                 financial backward             2500
# 8                                   Language barrier             7000
# 9                   Distance between school and home             1000

# %%
import numpy as np
import matplotlib.pyplot as mat
height = [1000, 15000, 5000, 1400, 100,2000,600,2500,7000,1000]
bars = ('Academic pressure', 'lack of interest', 'Child labour', 'Edu.not necessary', 'Bullying','Diseases','Constant failurer','financial backward','Language barrier','Far away')
y_pos = np.arange(len(bars))
mat.bar(y_pos, height, color = (0.5,0.1,0.5,0.6))
mat.ylim(0,16000)
mat.xticks(y_pos, bars,rotation='vertical')
mat.figure(figsize=(17,10))
mat.show()

# %%
df
# Out:
#     District Name       Boys    B.drop no      Girls  \
# 0       Ahmedabad   470423.0   17170.4395   380844.0
# 1          Amreli   144187.0    6791.2077   104832.0
# 2           Anand   179808.0    6275.2992   142036.0
# 3     Banaskantha   277490.0   17426.3720   177149.0
# 4         Bharuch   147484.0    7241.4644    68824.0
# 5       Bhavnagar   268108.0   12895.9948   220706.0
# 6           Botad   187988.0   14794.6556   123117.0
# 7           Dangs    25055.0    2287.5215    23918.0
# 8     Gandhinagar   125443.0    4904.8213    97864.0
# 9        Jamnagar   169875.0    6964.8750   120644.0
# 10   ChotaUdaipur    22130.0    1949.6530    15262.0
# 11          Kheda   211139.0   13787.3767   139500.0
# 12          Kutch   139500.0    7281.9000   109673.0
# 13        Mehsana   153916.0    7218.6604   117898.0
# 14      Mahisagar    47348.0    2353.1956    40276.0
# 15        Navsari    93651.0    5141.4399    87626.0
# 16    Panchmahals   113032.0    5787.2384    85260.0
# ...

# %%
df[df['Reason2'] == 'Excessive academic pressure from school and parents']
# Out:
#   District Name      Boys   B.drop no     Girls     Gdno     Total  \
# 0     Ahmedabad  470423.0  17170.4395  380844.0  11958.5  851267.0
#
#           dno           Reason1  \
# 0  28687.6979  lack of interest
#
#                                              Reason2                   Reason3
# 0  Excessive academic pressure from school and pa...  Bullying(fear of judged)

# %%
df[df['Reason1'] == 'Language Barrier(fail to understand the gujarati language)']
# Out:
#   District Name   Boys   BDP B.drop no    Girls    GDP     Gdno    Total  \
# 7         Dangs  25055  9.13   2287.52  23918.0  11.64  2784.06  48973.0
#
#       T%        dno                                            Reason1  \
# 7  10.29  5039.3217  Language Barrier(fail to understand the gujara...
#
#         Reason2                             Reason3
# 7  Child labour  Education Not Considered necesaary

# %%
dd = pd.read_excel('dropoutlist.xlsx','dropout of dang', columns = ['Villages', 'no.population',  
                                    'pre', 'primary', 
                                    'sec', 'teacher'] ) 

dd = dd.dropna(axis='columns',how='all')

# %%
dd
# Out:
#      sr.no            Villages  No.of population  no.of household  \
# 0      1.0               Dardi             204.0             40.0
# 1      2.0          Sawarkhadi             661.0            136.0
# 2      3.0             Kosimda            1841.0            396.0
# 3      4.0            Sajupada            1380.0            269.0
# 4      5.0            Khokhari             589.0            117.0
# 5      6.0    Bardipada (Saja)             926.0            163.0
# 6      7.0           Bandhpada             477.0             79.0
# 7      8.0              Dhulda             913.0            160.0
# 8      9.0              Girmal            1106.0            198.0
# 9     10.0            Burthadi             950.0            159.0
# 10    11.0            Gavdahad             731.0            140.0
# 11    12.0           Jamnyamal            1168.0            229.0
# 12    13.0             Singana             843.0            141.0
# ...

# %%
dd = pd.read_excel('dropoutlist.xlsx','dropout of dang', usecols = ['sr.no','Villages', 'No.of population',  
                                    'no.of household', 'preprimary school'] ) 

dd = dd.dropna(axis='columns',how='all')
dd[dd['preprimary school'] == 'c']
# Out:
#      sr.no          Villages  No.of population  no.of household  \
# 0      1.0             Dardi             204.0             40.0
# 1      2.0        Sawarkhadi             661.0            136.0
# 2      3.0           Kosimda            1841.0            396.0
# 3      4.0          Sajupada            1380.0            269.0
# 4      5.0          Khokhari             589.0            117.0
# 5      6.0  Bardipada (Saja)             926.0            163.0
# 6      7.0         Bandhpada             477.0             79.0
# 7      8.0            Dhulda             913.0            160.0
# 8      9.0            Girmal            1106.0            198.0
# 9     10.0          Burthadi             950.0            159.0
# 10    11.0          Gavdahad             731.0            140.0
# 11    12.0         Jamnyamal            1168.0            229.0
# 12    13.0           Singana             843.0            141.0
# 13    14.0           Nishana            1627.0            340.0
# ...

# %%
dd = pd.read_excel('dropoutlist.xlsx','dropout of dang', usecols = ['sr.no','Villages', 'No.of population',  
                                    'no.of household','no.primary school'] ) 
dd[dd['no.primary school'] == 2]
# Out:
#      sr.no                     Villages  No.of population  no.of household  \
# 4      5.0                     Khokhari             589.0            117.0
# 7      8.0                       Dhulda             913.0            160.0
# 11    12.0                    Jamnyamal            1168.0            229.0
# 12    13.0                      Singana             843.0            141.0
# 19    20.0                   Jamansonda             494.0            112.0
# 20    21.0                     Mokhamal             973.0            231.0
# 22    23.0                Kadmal(Subir)            1725.0            279.0
# 23    24.0                    Kasadbari             668.0            120.0
# 27    28.0                   Bhenskatri            1310.0            254.0
# 32    32.0                   Pandharmal             338.0             92.0
# 39    39.0                        Mahal             862.0            143.0
# ...

# %%
dd = pd.read_excel('dropoutlist.xlsx','dropout of dang', usecols = ['sr.no','Villages', 'No.of population',  
                                    'no.of household','no.of teachers'] ) 
dd
# Out:
#      sr.no            Villages  No.of population  no.of household  \
# 0      1.0               Dardi             204.0             40.0
# 1      2.0          Sawarkhadi             661.0            136.0
# 2      3.0             Kosimda            1841.0            396.0
# 3      4.0            Sajupada            1380.0            269.0
# 4      5.0            Khokhari             589.0            117.0
# 5      6.0    Bardipada (Saja)             926.0            163.0
# 6      7.0           Bandhpada             477.0             79.0
# 7      8.0              Dhulda             913.0            160.0
# 8      9.0              Girmal            1106.0            198.0
# 9     10.0            Burthadi             950.0            159.0
# 10    11.0            Gavdahad             731.0            140.0
# 11    12.0           Jamnyamal            1168.0            229.0
# 12    13.0             Singana             843.0            141.0
# ...

# %%
dd[dd['no.of teachers'] == 4]
# Out:
#      sr.no                     Villages  No.of population  no.of household  \
# 3      4.0                     Sajupada            1380.0            269.0
# 5      6.0             Bardipada (Saja)             926.0            163.0
# 7      8.0                       Dhulda             913.0            160.0
# 15    16.0                        Jamla             516.0            112.0
# 18    19.0                     Biliamba             578.0            113.0
# 24    25.0                        Hadol             517.0             96.0
# 35    35.0                  Khopri Amba             386.0             77.0
# 38    38.0                 Sawardakasad             327.0             63.0
# 40    40.0                   Dhongiamba             812.0            186.0
# 43    43.0                        Daher             881.0            196.0
# 47    47.0                      Amthawa             328.0             57.0
# ...

# %%
dd[dd['no.of teachers'] == 9]
# Out:
#      sr.no    Villages  No.of population  no.of household preprimary school  \
# 21    22.0      Jharan             731.0            154.0                 c
# 36    36.0  Divadyawan             664.0            156.0                 c
# 67    68.0      Kusmal             587.0            131.0                 c
# 109  113.0     Dhadhra             432.0             89.0                 C
# 124  128.0    Satbabla             286.0             72.0                 c
# 155  159.0     Borkhet             430.0             89.0                 b
# 197  201.0      Khapri             129.0             28.0                 c
# 212  216.0     Nimpada             651.0            101.0                 c
# 243  247.0      Bilmal             986.0            205.0                 c
# 285  289.0  Nimbarpada             411.0             85.0                 c
#
#     no.primary school Secondary school  no.of teachers
# 21                  1                c               9
# ...
